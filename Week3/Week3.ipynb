# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanA3160/PythonAssignments/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Statements

# %%
#Function Definitions

# %%
#Assign values to variable: name, goal, birth_year, current_year

# %%
name = "Alan Anderson"
goal = " I want to graduate college"
birth_year = 2000
current_year = 2026

# %%
#Calculate Age

# %%
age = current_year - birth_year

# %%
#Print top border

# %%
print("=" *25)

# %%
#Print bio sentence

# %%
print("My name is " + name + " and I am " + str(age) + " years old. " + "My goal is " +  goal  )
# Out:
# My name is Alan Anderson and I am 26 years old. My goal is  I want to graduate college

# %%
#Print bottom border

# %%
print("=" *25)
