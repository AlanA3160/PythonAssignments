# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanA3160/PythonAssignments/blob/main/Week7/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
def verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
 while True:
  entry = input("Enter your pin: ")
  if entry == "1234":
     print("Correct Pin!")
#    - Return True
     return True
  else:
    print("Incorrect Pin.")
# 2. Define withdraw(balance, amount):
def withdraw(balance, amount):
#    - Subtract the amount from the balance
#    - Return the new balance
 pass
#
#    - Check if enough money exists
#    - Return the new (or old) balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
# 2. Call verify_pin()
verify_pin()
# 3. Get withdrawal amount from user input
# 4. Update current_balance by calling withdraw()
# 5. Print the final balance
# Out:
# Enter your pin: 1234
# Correct Pin!
# True
