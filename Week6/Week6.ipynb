# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanA3160/PythonAssignments/blob/main/Week6/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# 1. Import math
import math
# FUNCTION DEFINITIONS
# 1. Define area(radius): returns pi * r squared
def area(radius):
  return math.pi * (radius**2)
# 2. Define circumference(radius): returns 2 * pi * r
def circumference(radius):
  return 2 * math.pi * radius
# 3. Define volume(radius, height):
def volume(radius, height):
# - Call area(radius) and multiply by height.
 base_area = area(radius)
# - Return the result.
 return base_area * height


# PROGRAM LOGIC
# 1. Input for radius (float)
radius_input = float(input("Enter the radius: "))
# 2. Call and print area and circumference.
print("Area:" , area(radius_input))
print("Circumference:" , circumference(radius_input))
# 3. Input for height (float)
height_input = float(input("Enter the height: "))
# 4. Call and print volume.
print("Volume: ", volume(radius_input, height_input))
# Out:
# Enter the radius: 5
# Area: 78.53981633974483
# Circumference: 31.41592653589793
# Enter the height: 10
# Volume:  785.3981633974483
