# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanA3160/PythonAssignments/blob/main/Week10/Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# Define add_players(player_list):
# Start a while loop until user types quit
# If input is not quit, append name to player_list

# Define is_on_roster(player_list, search_name)
# Check if search_name is in player_list
# Return true or false

# PROGRAM LOGIC
# 1. create empty roster list
# 2. call add_players
# 3. Get search name from user
# 4. Call is_on_roster and print result
