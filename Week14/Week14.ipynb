# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanA3160/PythonAssignments/blob/main/Week14/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS
# Create physical book representation
class Book:
# Def __init__(self, title, author):
 def __init__(self, title, author):
# Use self to set title
  self.title = title
# Use self to set author
  self.author = author
# Use self to set is_availble to True by default
  self.is_available = True

# Def __str__(self)
 def __str__(self):
# check if self.is_avaliable is True or False
  if self.is_available:
    availability = "Avaliable"
  else:
    availability = "Checked out"
# Return title and status
  return f"{self.title} by {self.author} - {availability}"

# Method checkout() that sets is_avaliable to false
 def checkout(self):
  self.is_available = False
# Method return_book() that sets is_avaliable to true
 def return_book(self):
   self.is_avaliable = True

#Testing
#print(f"Book Title: {test.title}")
#print(f"Available: {test.is_available}")

# PROGRAM LOGIC
# 1. create two seperate instances of the book class
book1 = Book("Think Python", "Allen B. Downey")
book2 = Book("The Hobbit", "J.R.R. Tolkien")
# 2. print status of both books
print("---LIBRARY STATUS---")
print(book1)
print(book2)
# 3. check out one of the books using your method
print(f"\n Checking Out '{book2.title }'...  ")
book2.checkout()
# 4. print both books again that shows the changed status
print("\n---UPDATED LIBRARY---")
print(book1)
print(book2)
# Out:
# ---LIBRARY STATUS---
# Think Python by Allen B. Downey - Avaliable
# The Hobbit by J.R.R. Tolkien - Avaliable
#
#  Checking Out 'The Hobbit'...
#
# ---UPDATED LIBRARY---
# Think Python by Allen B. Downey - Avaliable
# The Hobbit by J.R.R. Tolkien - Checked out
